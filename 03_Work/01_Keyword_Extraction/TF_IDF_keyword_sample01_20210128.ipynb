# %%
# http://blog.naver.com/PostView.nhn?blogId=vangarang&logNo=221072014624&categoryNo=35&parentCategoryNo=0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict

corpus = ['동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 무궁화 삼천리 화려 강산 대한사람 대한으로 길이 보전하세',
          '남산 위에 저 소나무 철갑을 두른 듯 바람서리 불변함은 우리 기상일세 무궁화 삼천리 화려 강산 대한사람 대한으로 길이 보전하세',
          '가을 하늘 공활한데 높고 구름 없이 밝은 달은 우리 가슴 일편단심일세 무궁화 삼천리 화려 강산 대한사람 대한으로 길이 보전하세',
          '이 기상과 이 맘으로 충성을 다하여 괴로우나 즐거우나 나라 사랑하세 무궁화 삼천리 화려 강산 대한사람 대한으로 길이 보전하세',
          #'오 필승 코리아 오 필승 코리아 오 필승 코리아 오 오레 오레 무궁화 삼천리 화려 강산 대한사람 대한으로 길이 보전하세'
          ]

# ============================================
# -- Get TFIDF
# ============================================
vectorizer = TfidfVectorizer()
sp_matrix = vectorizer.fit_transform(corpus)

word2id = defaultdict(lambda : 0)
for idx, feature in enumerate(vectorizer.get_feature_names()):
    word2id[feature] = idx
print('word2id:', word2id)
# Out:
# word2id: defaultdict(<function <lambda> at 0x7f2e15930158>, {'가슴': 0, '가을': 1, '강산': 2, '공활한데': 3, '괴로우나': 4, '구름': 5, '기상과': 6, '기상일세': 7, '길이': 8, '나라': 9, '남산': 10, '높고': 11, '다하여': 12, '달은': 13, '닳도록': 14, '대한사람': 15, '대한으로': 16, '동해물과': 17, '두른': 18, '마르고': 19, '만세': 20, '맘으로': 21, '무궁화': 22, '바람서리': 23, '밝은': 24, '백두산이': 25, '보우하사': 26, '보전하세': 27, '불변함은': 28, '사랑하세': 29, '삼천리': 30, '소나무': 31, '없이': 32, '우리': 33, '우리나라': 34, '위에': 35, '일편단심일세': 36, '즐거우나': 37, '철갑을': 38, '충성을': 39, '하느님이': 40, '하늘': 41, '화려': 42})

# %%
for i, sent in enumerate(corpus):
    print('====== document[%d] ======' % i)
    for token in sent.split():
        print('token:', token, ' ,i:', i, ' ,word2id[token]:', word2id[token], ' ,')
        print( [ (token, sp_matrix[i, word2id[token]])  ] )
# Out:
# ====== document[0] ======
# token: 동해물과  ,i: 0  ,word2id[token]: 17  ,
# [('동해물과', 0.3191703756876433)]
# token: 백두산이  ,i: 0  ,word2id[token]: 25  ,
# [('백두산이', 0.3191703756876433)]
# token: 마르고  ,i: 0  ,word2id[token]: 19  ,
# [('마르고', 0.3191703756876433)]
# token: 닳도록  ,i: 0  ,word2id[token]: 14  ,
# [('닳도록', 0.3191703756876433)]
# token: 하느님이  ,i: 0  ,word2id[token]: 43  ,
# [('하느님이', 0.3191703756876433)]
# token: 보우하사  ,i: 0  ,word2id[token]: 26  ,
# [('보우하사', 0.3191703756876433)]
# token: 우리나라  ,i: 0  ,word2id[token]: 35  ,
# [('우리나라', 0.3191703756876433)]
# token: 만세  ,i: 0  ,word2id[token]: 20  ,
# [('만세', 0.3191703756876433)]
# token: 무궁화  ,i: 0  ,word2id[token]: 22  ,
# [('무궁화', 0.15208639414296274)]
# token: 삼천리  ,i: 0  ,word2id[token]: 30  ,
# [('삼천리', 0.15208639414296274)]
# token: 화려  ,i: 0  ,word2id[token]: 45  ,
# [('화려', 0.15208639414296274)]
# token: 강산  ,i: 0  ,word2id[token]: 2  ,
# [('강산', 0.15208639414296274)]
# token: 대한사람  ,i: 0  ,word2id[token]: 15  ,
# [('대한사람', 0.15208639414296274)]
# token: 대한으로  ,i: 0  ,word2id[token]: 16  ,
# [('대한으로', 0.15208639414296274)]
# token: 길이  ,i: 0  ,word2id[token]: 8  ,
# [('길이', 0.15208639414296274)]
# token: 보전하세  ,i: 0  ,word2id[token]: 27  ,
# [('보전하세', 0.15208639414296274)]
# ====== document[1] ======
# token: 남산  ,i: 1  ,word2id[token]: 10  ,
# [('남산', 0.3090872636837591)]
# token: 위에  ,i: 1  ,word2id[token]: 36  ,
# [('위에', 0.3090872636837591)]
# token: 저  ,i: 1  ,word2id[token]: 0  ,
# [('저', 0.0)]
# token: 소나무  ,i: 1  ,word2id[token]: 31  ,
# [('소나무', 0.3090872636837591)]
# token: 철갑을  ,i: 1  ,word2id[token]: 39  ,
# [('철갑을', 0.3090872636837591)]
# token: 두른  ,i: 1  ,word2id[token]: 18  ,
# [('두른', 0.3090872636837591)]
# token: 듯  ,i: 1  ,word2id[token]: 0  ,
# [('듯', 0.0)]
# token: 바람서리  ,i: 1  ,word2id[token]: 23  ,
# [('바람서리', 0.3090872636837591)]
# token: 불변함은  ,i: 1  ,word2id[token]: 28  ,
# [('불변함은', 0.3090872636837591)]
# token: 우리  ,i: 1  ,word2id[token]: 34  ,
# [('우리', 0.24936965816838805)]
# token: 기상일세  ,i: 1  ,word2id[token]: 7  ,
# [('기상일세', 0.3090872636837591)]
# token: 무궁화  ,i: 1  ,word2id[token]: 22  ,
# [('무궁화', 0.14728173724738938)]
# token: 삼천리  ,i: 1  ,word2id[token]: 30  ,
# [('삼천리', 0.14728173724738938)]
# token: 화려  ,i: 1  ,word2id[token]: 45  ,
# [('화려', 0.14728173724738938)]
# token: 강산  ,i: 1  ,word2id[token]: 2  ,
# [('강산', 0.14728173724738938)]
# token: 대한사람  ,i: 1  ,word2id[token]: 15  ,
# [('대한사람', 0.14728173724738938)]
# token: 대한으로  ,i: 1  ,word2id[token]: 16  ,
# [('대한으로', 0.14728173724738938)]
# token: 길이  ,i: 1  ,word2id[token]: 8  ,
# [('길이', 0.14728173724738938)]
# token: 보전하세  ,i: 1  ,word2id[token]: 27  ,
# [('보전하세', 0.14728173724738938)]
# ====== document[2] ======
# token: 가을  ,i: 2  ,word2id[token]: 1  ,
# [('가을', 0.28321254711781696)]
# token: 하늘  ,i: 2  ,word2id[token]: 44  ,
# [('하늘', 0.28321254711781696)]
# token: 공활한데  ,i: 2  ,word2id[token]: 3  ,
# [('공활한데', 0.28321254711781696)]
# token: 높고  ,i: 2  ,word2id[token]: 11  ,
# [('높고', 0.28321254711781696)]
# token: 구름  ,i: 2  ,word2id[token]: 5  ,
# [('구름', 0.28321254711781696)]
# token: 없이  ,i: 2  ,word2id[token]: 32  ,
# [('없이', 0.28321254711781696)]
# token: 밝은  ,i: 2  ,word2id[token]: 24  ,
# [('밝은', 0.28321254711781696)]
# token: 달은  ,i: 2  ,word2id[token]: 13  ,
# [('달은', 0.28321254711781696)]
# token: 우리  ,i: 2  ,word2id[token]: 34  ,
# [('우리', 0.22849409976344964)]
# token: 가슴  ,i: 2  ,word2id[token]: 0  ,
# [('가슴', 0.28321254711781696)]
# token: 일편단심일세  ,i: 2  ,word2id[token]: 37  ,
# [('일편단심일세', 0.28321254711781696)]
# token: 무궁화  ,i: 2  ,word2id[token]: 22  ,
# [('무궁화', 0.13495229616593857)]
# token: 삼천리  ,i: 2  ,word2id[token]: 30  ,
# [('삼천리', 0.13495229616593857)]
# token: 화려  ,i: 2  ,word2id[token]: 45  ,
# [('화려', 0.13495229616593857)]
# token: 강산  ,i: 2  ,word2id[token]: 2  ,
# [('강산', 0.13495229616593857)]
# token: 대한사람  ,i: 2  ,word2id[token]: 15  ,
# [('대한사람', 0.13495229616593857)]
# token: 대한으로  ,i: 2  ,word2id[token]: 16  ,
# [('대한으로', 0.13495229616593857)]
# token: 길이  ,i: 2  ,word2id[token]: 8  ,
# [('길이', 0.13495229616593857)]
# token: 보전하세  ,i: 2  ,word2id[token]: 27  ,
# [('보전하세', 0.13495229616593857)]
# ====== document[3] ======
# token: 이  ,i: 3  ,word2id[token]: 0  ,
# [('이', 0.0)]
# token: 기상과  ,i: 3  ,word2id[token]: 6  ,
# [('기상과', 0.31917037568764334)]
# token: 이  ,i: 3  ,word2id[token]: 0  ,
# [('이', 0.0)]
# token: 맘으로  ,i: 3  ,word2id[token]: 21  ,
# [('맘으로', 0.31917037568764334)]
# token: 충성을  ,i: 3  ,word2id[token]: 40  ,
# [('충성을', 0.31917037568764334)]
# token: 다하여  ,i: 3  ,word2id[token]: 12  ,
# [('다하여', 0.31917037568764334)]
# token: 괴로우나  ,i: 3  ,word2id[token]: 4  ,
# [('괴로우나', 0.31917037568764334)]
# token: 즐거우나  ,i: 3  ,word2id[token]: 38  ,
# [('즐거우나', 0.31917037568764334)]
# token: 나라  ,i: 3  ,word2id[token]: 9  ,
# [('나라', 0.31917037568764334)]
# token: 사랑하세  ,i: 3  ,word2id[token]: 29  ,
# [('사랑하세', 0.31917037568764334)]
# token: 무궁화  ,i: 3  ,word2id[token]: 22  ,
# [('무궁화', 0.15208639414296277)]
# token: 삼천리  ,i: 3  ,word2id[token]: 30  ,
# [('삼천리', 0.15208639414296277)]
# token: 화려  ,i: 3  ,word2id[token]: 45  ,
# [('화려', 0.15208639414296277)]
# token: 강산  ,i: 3  ,word2id[token]: 2  ,
# [('강산', 0.15208639414296277)]
# token: 대한사람  ,i: 3  ,word2id[token]: 15  ,
# [('대한사람', 0.15208639414296277)]
# token: 대한으로  ,i: 3  ,word2id[token]: 16  ,
# [('대한으로', 0.15208639414296277)]
# token: 길이  ,i: 3  ,word2id[token]: 8  ,
# [('길이', 0.15208639414296277)]
# token: 보전하세  ,i: 3  ,word2id[token]: 27  ,
# [('보전하세', 0.15208639414296277)]
# ====== document[4] ======
# token: 오  ,i: 4  ,word2id[token]: 0  ,
# [('오', 0.0)]
# token: 필승  ,i: 4  ,word2id[token]: 42  ,
# [('필승', 0.6147275261108647)]
# token: 코리아  ,i: 4  ,word2id[token]: 41  ,
# [('코리아', 0.6147275261108647)]
# token: 오  ,i: 4  ,word2id[token]: 0  ,
# [('오', 0.0)]
# token: 필승  ,i: 4  ,word2id[token]: 42  ,
# [('필승', 0.6147275261108647)]
# token: 코리아  ,i: 4  ,word2id[token]: 41  ,
# [('코리아', 0.6147275261108647)]
# token: 오  ,i: 4  ,word2id[token]: 0  ,
# [('오', 0.0)]
# token: 필승  ,i: 4  ,word2id[token]: 42  ,
# [('필승', 0.6147275261108647)]
# token: 코리아  ,i: 4  ,word2id[token]: 41  ,
# [('코리아', 0.6147275261108647)]
# token: 오  ,i: 4  ,word2id[token]: 0  ,
# [('오', 0.0)]
# token: 오레  ,i: 4  ,word2id[token]: 33  ,
# [('오레', 0.4098183507405765)]
# token: 오레  ,i: 4  ,word2id[token]: 33  ,
# [('오레', 0.4098183507405765)]
# token: 무궁화  ,i: 4  ,word2id[token]: 22  ,
# [('무궁화', 0.09764031997560368)]
# token: 삼천리  ,i: 4  ,word2id[token]: 30  ,
# [('삼천리', 0.09764031997560368)]
# token: 화려  ,i: 4  ,word2id[token]: 45  ,
# [('화려', 0.09764031997560368)]
# token: 강산  ,i: 4  ,word2id[token]: 2  ,
# [('강산', 0.09764031997560368)]
# token: 대한사람  ,i: 4  ,word2id[token]: 15  ,
# [('대한사람', 0.09764031997560368)]
# token: 대한으로  ,i: 4  ,word2id[token]: 16  ,
# [('대한으로', 0.09764031997560368)]
# token: 길이  ,i: 4  ,word2id[token]: 8  ,
# [('길이', 0.09764031997560368)]
# token: 보전하세  ,i: 4  ,word2id[token]: 27  ,
# [('보전하세', 0.09764031997560368)]

# %%
keyword_dic = {}

for i, sent in enumerate(corpus):
    for token in sent.split():
        keyword_dic[token] = sp_matrix[i, word2id[token]]

sort_val_result = sorted(keyword_dic.items(), key=lambda x:x[1], reverse = True) 
print('sort_val_result:', sort_val_result)
# Out:
# sort_val_result: [('동해물과', 0.3134419204337589), ('백두산이', 0.3134419204337589), ('마르고', 0.3134419204337589), ('닳도록', 0.3134419204337589), ('하느님이', 0.3134419204337589), ('보우하사', 0.3134419204337589), ('우리나라', 0.3134419204337589), ('만세', 0.3134419204337589), ('기상과', 0.3134419204337589), ('맘으로', 0.3134419204337589), ('충성을', 0.3134419204337589), ('다하여', 0.3134419204337589), ('괴로우나', 0.3134419204337589), ('즐거우나', 0.3134419204337589), ('나라', 0.3134419204337589), ('사랑하세', 0.3134419204337589), ('남산', 0.30428832411070306), ('위에', 0.30428832411070306), ('소나무', 0.30428832411070306), ('철갑을', 0.30428832411070306), ('두른', 0.30428832411070306), ('바람서리', 0.30428832411070306), ('불변함은', 0.30428832411070306), ('기상일세', 0.30428832411070306), ('가을', 0.2795069582667278), ('하늘', 0.2795069582667278), ('공활한데', 0.2795069582667278), ('높고', 0.2795069582667278), ('구름', 0.2795069582667278), ('없이', 0.2795069582667278), ('밝은', 0.2795069582667278), ('달은', 0.2795069582667278), ('가슴', 0.2795069582667278), ('일편단심일세', 0.2795069582667278), ('우리', 0.2203664963495715), ('무궁화', 0.16356699702200667), ('삼천리', 0.16356699702200667), ('화려', 0.16356699702200667), ('강산', 0.16356699702200667), ('대한사람', 0.16356699702200667), ('대한으로', 0.16356699702200667), ('길이', 0.16356699702200667), ('보전하세', 0.16356699702200667), ('저', 0.0), ('듯', 0.0), ('이', 0.0)]
